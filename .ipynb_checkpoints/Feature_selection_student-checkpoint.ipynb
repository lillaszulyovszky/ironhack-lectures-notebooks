# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid") #white grid charts
# %matplotlib inline #the chart will sit under the code
# option so we can always see all columns
pd.set_option('display.max_columns', None) # just saying don't limit how many columns I can see
# Out:
# UsageError: unrecognized arguments: #the chart will sit under the code

# %%
data = pd.read_csv('unit4_partially_processed.csv') 
data.head()
# Out:
#   STATE   DOB MDMAUD GENDER DOMAIN    INCOME HOMEOWNR   HV1   HV2  HV3  HV4  \
# 0    IL  3712   XXXX      F     T2  3.878257            479   635    3    2
# 1    CA  5202   XXXX      M     S1  6.000000        H  5468  5218   12   10
# 2    NC     0   XXXX      M     R2  3.000000        U   497   546    2    1
# 3    CA  2801   XXXX      F     R2  1.000000        U  1000  1263    2    1
# 4    FL  2001   XXXX      F     S2  3.000000        H   576   594    4    3
#
#     IC1   IC2   IC3   IC4    IC5  NUMPROM  CARDPROM  CARDPM12  NUMPRM12  \
# 0   307   318   349   378  12883       74        27         6        14
# 1  1088  1096  1026  1037  36175       32        12         6        13
# 2   251   292   292   340  11576       63        26         6        14
# 3   386   388   396   423  15130       66        27         6        14
# 4   240   250   293   321   9836      113        43        10        25
#
#    MAXADATE RFA_2  NGIFTALL  TIMELAG    AVGGIFT      IC2_
# 0      9702   L4E        31      4.0   7.741935       Low
# 1      9702   L2G         3     18.0  15.666667      High
# 2      9702   L4E        27     12.0   7.481481       Low
# 3      9702   L4E        16      9.0   6.812500  Moderate
# 4      9702   L2F        37     14.0   6.864865       Low

# %%
#what's this XXXX?
data['MDMAUD'].value_counts()
# Out:
# XXXX    90290
# C1CM       59
# L1CM       44
# I1CM       34
# D2CM       27
# C2CM       23
# D1CM       19
# L2CM       14
# C1LM        8
# L1LM        8
# I2CM        7
# D5CM        5
# D5MM        5
# D2MM        4
# C5CM        3
# I1LM        3
# D5TM        3
# C2MM        3
# C2LM        2
# C5TM        1
# L1MM        1
# C1MM        1
# L2TM        1
# I2MM        1
# I5MM        1
# I5CM        1
# C5MM        1
# Name: MDMAUD, dtype: int64

# %% [markdown]
# ### Feature engineering - a few more examples

# %% [markdown]
# Add your notes here :
# - transforming the data for me to interpret and for the ML model as well
# - too many 0s in DOB, feeding in to the ML as is doesn't make sense
# - we don't want to exclude all these rows, just want to pull out the year of birts

# %%
# check how many people put 0 for age
len(data[data['DOB'] == 0])
# Out:
# 22507

# %% [markdown]
# NOTE : In the DOB column, the format is YYMM. We will use this info to get the year when they were born.

# %%
def year(x):
  x =str(x)
  if (len(x) < 4):
    return np.nan
  else:
    return int(x[:2])

# %%
import re
def year(x):
    x = str(x)
    if len(x)<4:
        return np.nan
    else:
        pattern = '\d\d'
        yr = re.findall(pattern,x)[0]
        return int(yr)

# %% [markdown]
# NOTE : our reference year is 1997 because the data is from a 1997 study.

# %%
data['year'] = list(map(year, data['DOB']))
data['age'] = 97 - data['year']

data['age'] = data['age'].fillna(np.mean(data['age'])) # introducing bias

# %%
# Now we can drop the column DOB as we have extracted the information we need from this column
data = data.drop(['DOB'], axis=1)
data = data.drop(['year'], axis=1)

# %%
data.head()
# Out:
#   STATE MDMAUD GENDER DOMAIN    INCOME HOMEOWNR   HV1   HV2  HV3  HV4   IC1  \
# 0    IL   XXXX      F     T2  3.878257            479   635    3    2   307
# 1    CA   XXXX      M     S1  6.000000        H  5468  5218   12   10  1088
# 2    NC   XXXX      M     R2  3.000000        U   497   546    2    1   251
# 3    CA   XXXX      F     R2  1.000000        U  1000  1263    2    1   386
# 4    FL   XXXX      F     S2  3.000000        H   576   594    4    3   240
#
#     IC2   IC3   IC4    IC5  NUMPROM  CARDPROM  CARDPM12  NUMPRM12  MAXADATE  \
# 0   318   349   378  12883       74        27         6        14      9702
# 1  1096  1026  1037  36175       32        12         6        13      9702
# 2   292   292   340  11576       63        26         6        14      9702
# 3   388   396   423  15130       66        27         6        14      9702
# 4   250   293   321   9836      113        43        10        25      9702
#
#   RFA_2  NGIFTALL  TIMELAG    AVGGIFT      IC2_       age
# 0   L4E        31      4.0   7.741935       Low  60.00000
# 1   L2G         3     18.0  15.666667      High  45.00000
# 2   L4E        27     12.0   7.481481       Low  59.51171
# 3   L4E        16      9.0   6.812500  Moderate  69.00000
# 4   L2F        37     14.0   6.864865       Low  77.00000

# %% [markdown]
# ### Feature selection- the challenge : which columns should we keep for our model?
#
# - tip 1 - check null values to drop a column
# - tip 2 - sense check which columns are likely to be useful to answer the question at hand...
# - tip 3 - check multicollinearity for numerical variables using correlation/ heat maps etc
#
# Things you can do : (your notes here)
#
# - value counts
# - plots
# - corr matrix
# - nulls
# - pairplots
# - discuss with others

# %%
# corrrelation matrix to look for things that correlate with each other - what do we have to get rid of?
data_corr = data[['INCOME', 'HV1', 'HV2', 'IC1', 'IC2', 'IC3', 'IC4', 'NUMPROM', 'CARDPROM', 'NGIFTALL', 'TIMELAG', 'AVGGIFT']]
corr_matrix=data_corr.corr(method='pearson')
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# ### why is multi collinearity a problem for linear regression ?
#
# Your notes here :
#
# - if 2 variables mean the same thing - then qweight doubled
# - the more columns, the more noise = inaccute predictions
# - slower performance
#
#
# ### How does the correlation matrix help ?
#
# Your notes here :
#
# - summarises all the relationships between numeric variables in one small space
# - highlight using color - easy to read
# - identify if there are areas to focus on
# - high correlation means their values are similar

# %%
corr_matrix # numeric less colourful version
# Out:
#             INCOME       HV1       HV2       IC1       IC2       IC3  \
# INCOME    1.000000  0.272562  0.281711  0.366982  0.355980  0.379572
# HV1       0.272562  1.000000  0.993351  0.674112  0.712827  0.704212
# HV2       0.281711  0.993351  1.000000  0.681722  0.721610  0.719277
# IC1       0.366982  0.674112  0.681722  1.000000  0.951175  0.975360
# IC2       0.355980  0.712827  0.721610  0.951175  1.000000  0.955173
# IC3       0.379572  0.704212  0.719277  0.975360  0.955173  1.000000
# IC4       0.366985  0.723701  0.740637  0.929769  0.973696  0.971342
# NUMPROM  -0.069502 -0.028515 -0.029011 -0.027508 -0.020158 -0.026578
# CARDPROM -0.070590 -0.039905 -0.040946 -0.035314 -0.028905 -0.035150
# NGIFTALL -0.109118 -0.061114 -0.062618 -0.063875 -0.058706 -0.065675
# TIMELAG   0.023798  0.017014  0.017883  0.021362  0.024058  0.024087
# AVGGIFT   0.084985  0.099967  0.102086  0.083434  0.087900  0.086453
#
#                IC4   NUMPROM  CARDPROM  NGIFTALL   TIMELAG   AVGGIFT
# INCOME    0.366985 -0.069502 -0.070590 -0.109118  0.023798  0.084985
# HV1       0.723701 -0.028515 -0.039905 -0.061114  0.017014  0.099967
# HV2       0.740637 -0.029011 -0.040946 -0.062618  0.017883  0.102086
# IC1       0.929769 -0.027508 -0.035314 -0.063875  0.021362  0.083434
# IC2       0.973696 -0.020158 -0.028905 -0.058706  0.024058  0.087900
# IC3       0.971342 -0.026578 -0.035150 -0.065675  0.024087  0.086453
# IC4       1.000000 -0.018057 -0.027588 -0.058687  0.025518  0.088880
# NUMPROM  -0.018057  1.000000  0.949394  0.795174  0.013489 -0.140556
# CARDPROM -0.027588  0.949394  1.000000  0.776598  0.021338 -0.189318
# NGIFTALL -0.058687  0.795174  0.776598  1.000000 -0.109979 -0.256253
# TIMELAG   0.025518  0.013489  0.021338 -0.109979  1.000000  0.075476
# AVGGIFT   0.088880 -0.140556 -0.189318 -0.256253  0.075476  1.000000

# %% [markdown]
# ### what can you see? do we need to investigate further ?
#
# what can we do to confirm the correlation?
#
# your notes here :
#
# -
# -
# -

# %%
sns.jointplot(x="HV1", y="HV2", data=data_corr, kind='reg',joint_kws={'line_kws':{'color':'black'}})

# %%
sns.jointplot(x="HV1", y="IC1", data=data_corr, kind='reg',joint_kws={'line_kws':{'color':'black'}})

# %%
sns.jointplot(x="HV1", y="IC2", data=data_corr, kind='reg',joint_kws={'line_kws':{'color':'black'}})

# %%
sns.jointplot(x="HV1", y="IC3", data=data_corr, kind='reg',joint_kws={'line_kws':{'color':'black'}})

# %%
sns.jointplot(x="HV1", y="IC4", data=data_corr, kind='reg',joint_kws={'line_kws':{'color':'black'}})

# %%
sns.jointplot(x="IC1", y="IC2", data=data_corr, kind='reg',joint_kws={'line_kws':{'color':'black'}})

# %% [markdown]
# ### what if anything has this revealed ? Can we drop some features at this stage?
#
# your notes here :
#
# -
# -
# -

# %% [markdown]
# #### what about calculating a line of best fit using linear regression, between two variables ?

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# ### what is r2 score? and can I 100% rely on it?
# https://blog.minitab.com/blog/adventures-in-statistics-2/regression-analysis-how-do-i-interpret-r-squared-and-assess-the-goodness-of-fit
#
# your notes here :
#
# -
# -
# -
#
#
#
# ### what is VIF?
# https://www.statisticshowto.com/variance-inflation-factor/
#
# your notes here :
#
# -
# -
# -

# %%
model = LinearRegression().fit(data_corr[['HV1']], data_corr[['HV2']])
model_r2 = model.score(data_corr[['HV1']], data_corr[['HV2']])
model_vif = 1/(1-model_r2)
print("The R2 of the model is: %5.3f" % (model_r2))
print("The VIF of the model is: %5.3f" % (model_vif))
# Out:
# The R2 of the model is: 0.987
# The VIF of the model is: 75.446

# %%
model = LinearRegression().fit(data_corr[['IC1']], data_corr[['IC2']])
model_r2 = model.score(data_corr[['IC1']], data_corr[['IC2']])
model_vif = 1/(1-model_r2)
print("The R2 of the model is: %5.3f" % (model_r2))
print("The VIF of the model is: %5.3f" % (model_vif))
# Out:
# The R2 of the model is: 0.905
# The VIF of the model is: 10.497

# %% [markdown]
# #### Let's see how we can automate some feature selection based on VIF.

# %%
# can't have any nulls when running this
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %%
data_corr.shape
# Out:
# (90569, 12)

# %% [markdown]
# NOTE: before using these techniques you must ensure there are no Nulls or NANs in my data - as these functions cannot handle missing values

# %%
data_corr.isnull().sum().sort_values(ascending=False)
# Out:
# TIMELAG     9653
# INCOME         0
# HV1            0
# HV2            0
# IC1            0
# IC2            0
# IC3            0
# IC4            0
# NUMPROM        0
# CARDPROM       0
# NGIFTALL       0
# AVGGIFT        0
# dtype: int64

# %% [markdown]
# As we can see there are loads of missing values in timelag. we have been through various methods to interpolate, predict, or drop these values already.
# Lets use the simple replace with mean technique for this exercise

# %%
data_corr.fillna(data_corr.mean(), inplace=True)
# Out:
# /Users/lilmac/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
#remember to check this has worked as expected

# %%
# VIF function: 
# We are using add_constant here as the VIF method in python expects the addition of a constant terms in the X features.
# (namely the intercept term). It uses OLS but does not add the constant itself. 

vif = {}
data_corr = add_constant(data_corr)
#data_corr

for i in np.arange(data_corr.shape[1]):
    column_name = data_corr.columns[i]
    value = variance_inflation_factor(np.array(data_corr), i)
    vif[column_name] = value

# %%
# Code to use the variance_inflation_factor technique to remove highly correlated columns

flag = True
threshold = 50
data_corr = add_constant(data_corr)
while flag is True:
    #print(data_corr.head())
    flag = False
    values = [variance_inflation_factor(np.array(data_corr), i) for i in np.arange(data_corr.shape[1])]
    #print(values)
    if max(values)> threshold:
        col_index = values.index(max(values))
        column_name = data_corr.columns[col_index]
        data_corr = data_corr.drop([column_name], axis=1)
        flag = True

# %% [markdown]
# #### Summary re effects of Multicollinearity:
#
# Your Notes here
#
# -
#
# -
#
# -

# %% [markdown]
# # Activity
#
# Comparing the VIF method and the correlation matrix to perform feature selection.
#
# Do you think it is better to use VIF or correlation matrix threshold for feature selection?

# %%
# using corr

flag= True
while flag is True:
    flag = False
    for i in range(1, corr_matrix.shape[1]):
        if corr_matrix.iloc[i,range(i)].max() > 0.9:
            print(corr_matrix.columns[corr_matrix.iloc[i,range(i)].argmax()])
            col_name = corr_matrix.columns[corr_matrix.iloc[i,range(i)].argmax()]
            corr_matrix.drop([col_name], axis=1, inplace=True)
            corr_matrix.drop([col_name], inplace=True)

            flag = True
            break

print(corr_matrix.columns)
# Out:
# HV1
# IC1
# IC2
# IC3
# NUMPROM
# Index(['INCOME', 'HV2', 'IC4', 'CARDPROM', 'NGIFTALL', 'TIMELAG', 'AVGGIFT'], dtype='object')

# %%
# using VIF

flag = True
threshold = 50
data_corr = add_constant(data_corr)
while flag is True:
    #print(data_corr.head())
    flag = False
    values = [variance_inflation_factor(np.array(data_corr), i) for i in np.arange(data_corr.shape[1])]
    #print(values)
    if max(values)> threshold:
        col_index = values.index(max(values))
        column_name = data_corr.columns[col_index]
        data_corr = data_corr.drop([column_name], axis=1)
        flag = True

print(data_corr.columns)
# Out:
# Index(['const', 'INCOME', 'HV1', 'IC1', 'IC2', 'IC4', 'NUMPROM', 'CARDPROM',
#        'NGIFTALL', 'TIMELAG', 'AVGGIFT'],
#       dtype='object')

# %% [markdown]
# ### Chi-square tests for independence of categorical variables
#
# Your notes here :
#
# - looking for corr between categorical features (cant use corr matrix)
# -
# -

# %% [markdown]
# https://towardsdatascience.com/chi-square-test-for-feature-selection-in-machine-learning-206b1f0b8223

# %%
data_crosstab = pd.crosstab(data['DOMAIN'], data['RFA_2'], margins = False)
data_crosstab
# Out:
# RFA_2   L1E   L1F   L1G  L2E   L2F  L2G  L3D   L3E  L3F  L3G  L4D  L4E  L4F  \
# DOMAIN
#         156   595   281  134   248  129   61   169   95   33   98   92   50
# C1      249  1842   926  283   689  328  114   421  230  113  210  219  108
# C2      413  2415  1002  436   916  383  205   640  277  153  434  318  163
# C3      300  1620   605  298   558  199  155   410  166   54  319  228  106
# R1       62   419   185   52   157   72   26   113   52   24   50   37   24
# R2      782  4041  1532  778  1472  597  397  1060  480  190  742  535  286
# R3      311  1486   441  280   488  178  165   380  143   53  319  200   93
# S1      410  3627  1884  411  1231  695  198   751  438  193  368  344  208
# S2      396  2631  1016  401   995  312  184   673  332  126  383  346  191
# S3       81   633   198   79   205   53   56   157   68   31  117   89   32
# T1      212  1534   753  204   542  273   91   369  197   74  181  142   98
# T2      636  3711  1356  651  1341  549  305  1023  417  169  643  535  275
# T3      130   669   202  109   226   86   68   201   72   23  148   91   48
# U1      162  1451   709  207   493  239   63   305  143   76  127  162   79
# U2      148  1048   422  165   366  142   67   230  105   59  128  117   82
# U3      140   861   288  121   257   96   69   209   91   30  109  114   67
# U4       79   624   207   72   214   79   43   133   46   24   73   78   41
#
# RFA_2   L4G
# DOMAIN
#          35
# C1       61
# C2       79
# C3       38
# R1       12
# R2      114
# R3       35
# S1      108
# S2       68
# S3       18
# T1       42
# T2      106
# T3       19
# U1       43
# U2       32
# U3       32
# U4       22

# %% [markdown]
# What did the contingency table show ?
#
# your notes here
#
# -
# -
# -
#
# H0 (Null Hypothesis) - assumes that there is no association between the two variables.
#
# Ha (Alternate Hypothesis) - assumes that there is an association between the two variables.

# %% [markdown]
# #### What are the three important values that we measure in order to calculate the Chi-square test statistic?
#
# Your notes here:
#
#     - chi-square statistic
#     - p-value (normally comparing to 0.05 s a treshold)
#     - degrees of freedom back
#     - table of results

# %%
from scipy.stats import chi2_contingency
chi2_contingency(data_crosstab, correction=False)
# have a high correlation between these categories
# Out:
# (1397.7553798894764,
#  3.3725088859824856e-175,
#  208,
#  array([[ 112.12878579,  701.72390111,  288.47875101,  112.46514812,
#           249.82110877,  105.95413442,   54.46667182,  174.04348066,
#            80.53475251,   34.23688017,  106.89114377,   87.62238735,
#            46.87449348,   20.75836103],
#         [ 298.5119743 , 1868.14639667,  767.99513078,  299.40744626,
#           665.0798176 ,  282.07366759,  145.00249534,  463.34277733,
#           214.40157228,   91.14625313,  284.56819662,  233.27044574,
#           124.79041394,   55.26341243],
#         [ 403.68424074, 2526.33503737, 1038.57653281,  404.89520697,
#           899.40191456,  381.45436076,  196.09003081,  626.58852367,
#           289.93991322,  123.25906215,  384.82776668,  315.45670152,
#           168.75679316,   74.73391558],
#         [ 260.53453168, 1630.47612318,  670.28886264,  261.31607945,
#           580.4666939 ,  246.18754762,  126.55491393,  404.39514624,
#           187.12486612,   79.55039804,  248.3647164 ,  203.59319414,
#           108.91426426,   48.23266239],
#         [  66.21575815,  414.39118241,  170.35624772,   66.41439124,
#           147.52763087,   62.56942221,   32.16437192,  102.77843412,
#            47.55843611,   20.21801058,   63.12275723,   51.743919  ,
#            27.68093939,   12.25849904],
#         [ 670.19622608, 4194.21923616, 1724.24385827,  672.20667116,
#          1493.18627787,  633.29019863,  325.54849893, 1040.26172311,
#           481.35799225,  204.63458799,  638.8907242 ,  523.72094204,
#           280.16988153,  124.07318177],
#         [ 235.59412161, 1474.39415252,  606.12355221,  236.30085349,
#           524.8998664 ,  222.62054345,  114.44008436,  365.68326911,
#           169.21180536,   71.93520962,  224.58929656,  184.10365578,
#            98.48813612,   43.61545341],
#         [ 559.92251212, 3504.10473782, 1440.53773366,  561.60215968,
#          1247.49823891,  529.08898188,  271.98293014,  869.09763826,
#           402.15561616,  170.9641268 ,  533.76800009,  437.54818978,
#           234.07088518,  103.65824951],
#         [ 415.02079078, 2597.28138767, 1067.742583  ,  416.26576422,
#           924.65956343,  392.16663538,  201.59677152,  644.18483145,
#           298.08221356,  126.72051143,  395.6347757 ,  324.31558259,
#           173.49594232,   76.83264693],
#         [  93.62959732,  585.95235677,  240.88506001,   93.91046605,
#           208.60521812,   88.47364992,   45.48067219,  145.32950568,
#            67.24799876,   28.5884243 ,   89.25606996,   73.16630414,
#            39.14106372,   17.33361305],
#         [ 242.80828981, 1519.54182999,  624.68376597,  243.53666265,
#           540.97291568,  229.43744548,  117.9443739 ,  376.88091952,
#           174.39326922,   74.13795007,  231.46648412,  189.74112555,
#           101.50395831,   44.95100973],
#         [ 603.77434884, 3778.53812011, 1553.35731873,  605.58554251,
#          1345.19941702,  570.5260078 ,  293.28400446,  937.16335612,
#           433.65151432,  184.35364197,  575.57147589,  471.81595248,
#           252.40277578,  111.77652398],
#         [ 107.80028487,  674.63529464,  277.34262275,  108.12366262,
#           240.1772792 ,  101.8639932 ,   52.36409809,  167.32489042,
#            77.4258742 ,   32.9152359 ,  102.76483123,   84.23990549,
#            45.06500017,   19.95702724],
#         [ 219.4653027 , 1373.45684506,  564.62821716,  220.12365158,
#           488.96512052,  207.3798982 ,  106.60549415,  340.64852212,
#           157.6275326 ,   67.01051132,  209.21387009,  171.49988407,
#            91.74561936,   40.62953108],
#         [ 160.30912343, 1003.24588987,  412.43446433,  160.79001645,
#           357.16611644,  151.48130155,   77.87031987,  248.82778876,
#           115.13952898,   48.94803962,  152.82093211,  125.27263192,
#            67.0158774 ,   29.67796928],
#         [ 127.99995583,  801.04879153,  329.31122128,  128.38392828,
#           285.18181718,  120.95131888,   62.17610882,  198.67831156,
#            91.93397299,   39.08290916,  122.0209564 ,  100.02482085,
#            53.5093023 ,   23.69658492],
#         [  89.40415595,  559.50871711,  230.01407766,   89.67234926,
#           199.19100354,   84.48089302,   43.42815975,  138.77088187,
#            64.21314136,   27.29824774,   85.22800296,   69.86435756,
#            37.37465358,   16.55135863]]))

# %% [markdown]
# #### What did you learn using the chi squared test and are there any further columns/features we could drop at this stage ?
#
# Your notes here :
#
# -
# -
# -
